# %%
import os
os.chdir('/content/drive/MyDrive/HPC (1)/')
# !ls
# Out:
# 'Assignments_Behnoud Shafiezadeh Kenari (5655740)- Sina Hatami (5447389) - Shayan Alvansazyazdi (5447411) .gdoc'
# 'Cuda_Assignment 3.ipynb'
#  Cuda_Homework
#  Cuda_Homework.cu
#  home_work
#  home_work.cu

# %%
# with grid size <<<32,32>>>
# !nvcc -o Cuda_Homework Cuda_Homework.cu -lm

# %%
# !./Cuda_Homework 1000 1000
# Out:
# input matrix dimensions: 1000 x 1000
# CPU Version, Elapsed time (s) = 2.17
# GPU Version, Elapsed time (s) = 0.00
# Problem! The Max Error of 6.16635 is NOT within acceptable bounds.

# %%
# !./Cuda_Homework 5000 5000
# Out:
# input matrix dimensions: 5000 x 5000
# CPU Version, Elapsed time (s) = 59.24
# GPU Version, Elapsed time (s) = 0.00
# Problem! The Max Error of 6.26814 is NOT within acceptable bounds.

# %%
# !./Cuda_Homework 10000 10000
# Out:
# input matrix dimensions: 10000 x 10000
# CPU Version, Elapsed time (s) = 239.49
# GPU Version, Elapsed time (s) = 0.00
# Problem! The Max Error of 6.23431 is NOT within acceptable bounds.

# %%
# with grid size <<<10,10>>>
# !nvcc -o home_work home_work.cu -lm

# %%
# !./home_work  1000 1000
# Out:
# input matrix dimensions: 1000 x 1000
# CPU Version, Elapsed time (s) = 2.14
# GPU Version, Elapsed time (s) = 0.13
# The Max Error of 0.00001 is within acceptable bounds.

# %%
# !./home_work  5000 5000
# Out:
# input matrix dimensions: 5000 x 5000
# CPU Version, Elapsed time (s) = 60.01
# GPU Version, Elapsed time (s) = 0.37
# The Max Error of 0.00002 is within acceptable bounds.

# %%
# !./home_work  10000 10000
# Out:
# input matrix dimensions: 10000 x 10000
# CPU Version, Elapsed time (s) = 246.63
# GPU Version, Elapsed time (s) = 1.26
# The Max Error of 0.00002 is within acceptable bounds.

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2299.998
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs mmio_stale_data retbleed
# bogomips	: 4599.99
# clflush size	: 64
# cache_alignment	: 64
# ...

# %%
# !cat /proc/cpuinfo | grep -i "processor\|cores\|siblings"
# Out:
# processor	: 0
# siblings	: 2
# cpu cores	: 1
# processor	: 1
# siblings	: 2
# cpu cores	: 1

# %%
# !nvidia-smi
# Out:
# Sun Feb 25 10:09:18 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              15W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...
